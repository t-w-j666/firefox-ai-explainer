# %% [markdown]
# 2026.5.10
# ---操作---
# 1，增加了提示词方案设置功能，但出现很多bug。

# %% [markdown]
# 2026.5.10
# ---操作---
# 1，日志问题基本解决了，后续可以继续打磨。
# 2，拿了火狐的amo签名，插件可以一直待在浏览器了。
# ---规划---
# 保持5.9的计划

# %% [markdown]
# 2026.5.9
# ---操作---
# 1，增加了日志功能，但不是很满意，基于这个功能并不是很必要，决定先不管保持现状，后续需要修改。
# 2，已经搞定设置界面和openai的接口格式，额外添加了方案配置保存功能，解决了每个模型使用前都要配置的麻烦。
# ---规划---
# 1，希望解决无法对输出内容重新划选讲解的问题，并且要求实现多个悬浮窗同时存在。
# 2，希望增加对话记录保存功能，方便查看历史记录。

# %% [markdown]
# 2026.5.8
# ---规划---
# 1，需要将模型接口改为openai api格式，然后搞一个设置页面
# 然后研究下怎么做个正式插件。
